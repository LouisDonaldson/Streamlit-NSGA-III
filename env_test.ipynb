# %% [markdown]
# # Comparison of RL envrionment and simulated environment for GA

# %%
from classes.data_handler import DataHandler as _data_handler
from classes.osw_environment_new import Environment
from classes.environment_handler import EnvironmentHandler

import pandas as pd

import random

# %%
days = 7
generations = 10
population_size = 10

# %%
population = [[]] * 7

upper_bounds = 27 * 6 + 1
print(upper_bounds)

for x in range(0, days):
    population[x] = [[random.randint(0, upper_bounds), random.randint(0, upper_bounds), random.randint(0, upper_bounds)] for _ in range(days)]

schedule_to_simulate = population[0]

env_handler = EnvironmentHandler(schedule_to_simulate,_data_handler(),Environment, number_of_days=days, _start_day=0)
env_handler.RunSim(verbose=False, episodes=7)

# %%
env = Environment(0,0,_data_handler(),0,None)

for i in range(0, 164):
    print(i)
    print(env.interpret_action(i))

# %%
from classes.data_handler import DataHandler as _data_handler
from classes.osw_environment_new import Environment
from classes.environment_handler import EnvironmentHandler

import pandas as pd

import random

schedule = [[5,123,40],[5, 45, 22], [2,2,45]]
data_handler = _data_handler()
data_handler.BeginImport()

data_handler.mast_df.head()

env_handler = EnvironmentHandler(schedule,data_handler,Environment,3,39,None)
env_handler.RunSim(verbose=False)
print(env_handler.reward["new_Power_Generated"])
# Out:
# c:\Users\lj200\OneDrive\Documents\GitHub\Streamlit-NSGA-III
# c:\Users\lj200\OneDrive\Documents\GitHub\Streamlit-NSGA-III
# Possible power: 26442.0 | Turbine Health: 95.1229424500714% | Actual power: 25152.40844264788
# Possible power: 26442.0 | Turbine Health: 95.1229424500714% | Actual power: 25152.40844264788
# Possible power: 26442.0 | Turbine Health: 95.1229424500714% | Actual power: 25152.40844264788
# Possible power: 26442.0 | Turbine Health: 96.07894391523232% | Actual power: 25405.19435006573
# Possible power: 26442.0 | Turbine Health: 96.07894391523232% | Actual power: 25405.19435006573
# Possible power: 26442.0 | Turbine Health: 96.07894391523232% | Actual power: 25405.19435006573
# Possible power: 26442.0 | Turbine Health: 100.0% | Actual power: 26442.0
# Possible power: 26442.0 | Turbine Health: 93.23938199059482% | Actual power: 24654.357385953084
# Possible power: 26442.0 | Turbine Health: 95.1229424500714% | Actual power: 25152.40844264788
# Possible power: 26442.0 | Turbine Health: 93.23938199059482% | Actual power: 24654.357385953084
# Possible power: 26442.0 | Turbine Health: 96.07894391523232% | Actual power: 25405.19435006573
# Possible power: 26442.0 | Turbine Health: 94.17645335842487% | Actual power: 24902.137797034702
# Possible power: 26442.0 | Turbine Health: 93.23938199059482% | Actual power: 24654.357385953084
# Possible power: 26442.0 | Turbine Health: 92.31163463866358% | Actual power: 24409.042431155423
# Possible power: 26442.0 | Turbine Health: 93.23938199059482% | Actual power: 24654.357385953084
# Possible power: 26442.0 | Turbine Health: 91.39311852712282% | Actual power: 24166.168400941817
# Possible power: 26442.0 | Turbine Health: 94.17645335842487% | Actual power: 24902.137797034702
# Possible power: 26442.0 | Turbine Health: 94.17645335842487% | Actual power: 24902.137797034702

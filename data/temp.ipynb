# %%
import json
import pandas as pd

df = pd.read_json("buoy.json")
df.to_csv("wave_data.csv", index=False)
# Out:
# C:\Users\lj200\AppData\Local\Temp\ipykernel_76532\1110723508.py:9: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   df = pd.read_json("buoy.json")

# %%
import pandas as pd

import pandas as pd

def build_daily_averages(input_csv, output_csv):
    # Load CSV with header
    df = pd.read_csv(input_csv)

    # Convert the Date column to datetime
    df["TIMESTAMP"] = pd.to_datetime(df["TIMESTAMP"], errors="coerce")

    # Extract the actual calendar date (YYYY-MM-DD)
    df["actual_day"] = df["TIMESTAMP"].dt.date

    # Assign sequential day numbers based on when the date changes
    df["day_number"] = (df["actual_day"] != df["actual_day"].shift()).cumsum()

    # Compute averages for each day (numeric columns only)
    daily_avg = df.groupby("day_number").mean(numeric_only=True)

    # Save to CSV
    daily_avg.to_csv(output_csv)
    daily_avg.to_json("mast_averages.json", orient="records", indent=2)

    print(f"Saved daily averages to {output_csv}")


build_daily_averages("new_mast.csv", "mast_averages.csv")
# Out:
# Saved daily averages to mast_averages.csv
# C:\Users\lj200\AppData\Local\Temp\ipykernel_123816\2442974658.py:7: DtypeWarning: Columns (22,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(input_csv)

# %%
df = pd.read_csv("daily_averages.csv")
daily_avg = df.groupby("day_number").mean(numeric_only=True)
daily_avg.to_json("daily_averages.json", orient="records", indent=2)
